# %%
import pandas as pd  # For data manipulation and analysis
import numpy as np  # For numerical computations

# %%
import os  # For interacting with the operating system
import sys  # For system-specific parameters and functions

# %%
# librosa is a Python library for analyzing audio and music. It can be used to extract the data from the audio files we will see it later.
import librosa
import librosa.display
import seaborn as sns  # For statistical data visualization
import matplotlib.pyplot as plt  # For creating plots and visualizations

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder  # For data preprocessing
from sklearn.metrics import confusion_matrix, classification_report  # For evaluating model performance
from sklearn.model_selection import train_test_split  # For splitting data into training and testing sets

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.16.1

# %%
# !pip install --upgrade tensorflow keras
# Out:
# ...
# WARNING: Ignoring invalid distribution -umpy (c:\users\naimu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eras (c:\users\naimu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\naimu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\naimu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eras (c:\users\naimu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\naimu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\naimu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eras (c:\users\naimu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\naimu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\naimu\anaconda3\lib\site-packages)
# ...

# %%
# To play the audio files
import IPython.display as ipd
from IPython.display import Audio
import tensorflow.keras as keras  # Update import statement
from tensorflow.keras.preprocessing import sequence  # Update import statement
from tensorflow.keras.models import Sequential  # Update import statement
from tensorflow.keras.layers import Dense, Embedding, LSTM, BatchNormalization, GRU  # Update import statement
from tensorflow.keras.preprocessing.text import Tokenizer  # Update import statement
from tensorflow.keras.preprocessing.sequence import pad_sequences  # Update import statement
from tensorflow.keras.utils import to_categorical  # Update import statement
from tensorflow.keras.layers import Input, Flatten, Dropout, Activation  # Update import statement
from tensorflow.keras.layers import Conv1D, MaxPooling1D, AveragePooling1D  # Update import statement
from tensorflow.keras.models import Model  # Update import statement
from tensorflow.keras.callbacks import ModelCheckpoint  # Update import statement
from tensorflow.keras.optimizers import SGD  # Update import statement

# %%
import warnings  # For handling warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning) 
import tensorflow as tf  # For building deep learning models
print("Done")
# Out:
# Done

# %%
import os

# Define the path to the directory containing the RAVDESS dataset
ravdess = "C:/Users/naimu/Music/Speech Recognition ML DL AI/Dataset/emotional speech dataset"

# List the contents of the directory
ravdess_directory_list = os.listdir(ravdess)
print(ravdess_directory_list)
# Out:
# ['OAF_angry', 'OAF_disgust', 'OAF_Fear', 'OAF_happy', 'OAF_neutral', 'OAF_Pleasant_surprise', 'OAF_Sad', 'YAF_angry', 'YAF_disgust', 'YAF_fear', 'YAF_happy', 'YAF_neutral', 'YAF_pleasant_surprised', 'YAF_sad']

# %%
Crema = "C:/Users/naimu/Music/Speech Recognition ML DL AI/Dataset/AudioWAV"
Tess = "C:/Users/naimu/Music/Speech Recognition ML DL AI/Dataset/emotional speech dataset"
Savee = "C:/Users/naimu/Music/Speech Recognition ML DL AI/Dataset/surrey ALL"

# %%
import os

ravdess = "C:/Users/naimu/Music/Speech Recognition ML DL AI/Dataset/emotional speech dataset/"
ravdess_directory_list = os.listdir(ravdess)
print(ravdess_directory_list)

file_emotion = []
file_path = []

for i in ravdess_directory_list:
    # as their are 24 different actors in our previous directory we need to extract files for each actor.
    actor = os.listdir(os.path.join(ravdess, i))
    print("Actor:", actor)
    for f in actor:
        print("Filename:", f)  # Print filename for debugging
        part = f.split('.')[0].split('-')
        print("Parts:", part)
        # Check if the filename has enough parts
        if len(part) >= 3:
            # third part in each file represents the emotion associated with that file.
            file_emotion.append(int(part[2]))
            file_path.append(os.path.join(ravdess, i, f))
        else:
            print("Skipping file:", f, "as it doesn't have enough parts")
# Out:
# ['OAF_angry', 'OAF_disgust', 'OAF_Fear', 'OAF_happy', 'OAF_neutral', 'OAF_Pleasant_surprise', 'OAF_Sad', 'YAF_angry', 'YAF_disgust', 'YAF_fear', 'YAF_happy', 'YAF_neutral', 'YAF_pleasant_surprised', 'YAF_sad']
# ...

# %%
# dataframe for emotion of files
emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])
# dataframe for path of files.
path_df = pd.DataFrame(file_path, columns=['Path'])
ravdess_df = pd.concat([emotion_df, path_df], axis=1)
# changing integers to actual emotions.
ravdess_df.Emotions.replace({1:'neutral', 2:'neutral', 3:'happy', 4:'sad', 5:'angry', 6:'fear', 7:'disgust',
                             8:'surprise'},
                            inplace=True)
print(ravdess_df.head())
print("______________________________________________")
print(ravdess_df.tail())
print("_______________________________________________")
print(ravdess_df.Emotions.value_counts())
# Out:
# Empty DataFrame
# Columns: [Emotions, Path]
# Index: []
# ______________________________________________
# Empty DataFrame
# Columns: [Emotions, Path]
# Index: []
# _______________________________________________
# Series([], Name: Emotions, dtype: int64)

# %%
crema_directory_list = os.listdir(Crema)

file_emotion = []
file_path = []

for file in crema_directory_list:
    # storing file paths
    file_path.append(Crema + file)
    # storing file emotions
    part=file.split('_')
    if part[2] == 'SAD':
        file_emotion.append('sad')
    elif part[2] == 'ANG':
        file_emotion.append('angry')
    elif part[2] == 'DIS':
        file_emotion.append('disgust')
    elif part[2] == 'FEA':
        file_emotion.append('fear')
    elif part[2] == 'HAP':
        file_emotion.append('happy')
    elif part[2] == 'NEU':
        file_emotion.append('neutral')
    else:
        file_emotion.append('Unknown')
        
# dataframe for emotion of files
emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])

# dataframe for path of files.
path_df = pd.DataFrame(file_path, columns=['Path'])
Crema_df = pd.concat([emotion_df, path_df], axis=1)
Crema_df.head()
print(Crema_df.Emotions.value_counts())
# Out:
# angry      1271
# disgust    1271
# fear       1271
# happy      1271
# sad        1271
# neutral    1087
# Name: Emotions, dtype: int64

# %%
tess_directory_list = os.listdir(Tess)

file_emotion = []
file_path = []

for dir_name in tess_directory_list:
    # Construct the full directory path
    full_dir_path = os.path.join(Tess, dir_name)
    
    # Check if it's a directory
    if os.path.isdir(full_dir_path):
        # List files in the directory
        files_in_dir = os.listdir(full_dir_path)
        for file in files_in_dir:
            # Construct the full file path
            full_file_path = os.path.join(full_dir_path, file)
            
            # Extract emotion from file name
            part = file.split('.')[0]
            part = part.split('_')[-1]  # Assuming emotion is the last part after splitting by '_'
            
            # Append emotion and file path to lists
            file_emotion.append(part)
            file_path.append(full_file_path)

# Create DataFrame
emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])
path_df = pd.DataFrame(file_path, columns=['Path'])
Tess_df = pd.concat([emotion_df, path_df], axis=1)
print(Tess_df.head())

# Print emotion value counts
print(Tess_df.Emotions.value_counts())
# Out:
#   Emotions                                               Path
# 0    angry  C:/Users/naimu/Music/Speech Recognition ML DL ...
# 1    angry  C:/Users/naimu/Music/Speech Recognition ML DL ...
# 2    angry  C:/Users/naimu/Music/Speech Recognition ML DL ...
# 3    angry  C:/Users/naimu/Music/Speech Recognition ML DL ...
# 4    angry  C:/Users/naimu/Music/Speech Recognition ML DL ...
# angry      400
# disgust    400
# fear       400
# happy      400
# neutral    400
# ps         400
# sad        400
# Name: Emotions, dtype: int64

# %%
savee_directory_list = os.listdir(Savee)

file_emotion = []
file_path = []

for file in savee_directory_list:
    file_path.append(Savee + file)
    part = file.split('_')[1]
    ele = part[:-6]
    if ele=='a':
        file_emotion.append('angry')
    elif ele=='d':
        file_emotion.append('disgust')
    elif ele=='f':
        file_emotion.append('fear')
    elif ele=='h':
        file_emotion.append('happy')
    elif ele=='n':
        file_emotion.append('neutral')
    elif ele=='sa':
        file_emotion.append('sad')
    else:
        file_emotion.append('surprise')
        
# dataframe for emotion of files
emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])

# dataframe for path of files.
path_df = pd.DataFrame(file_path, columns=['Path'])
Savee_df = pd.concat([emotion_df, path_df], axis=1)
Savee_df.head()
print(Savee_df.Emotions.value_counts())
# Out:
# neutral     120
# angry        60
# disgust      60
# fear         60
# happy        60
# sad          60
# surprise     60
# Name: Emotions, dtype: int64

# %%
# creating Dataframe using all the 4 dataframes we created so far.
data_path = pd.concat([ravdess_df, Crema_df, Tess_df, Savee_df], axis = 0)
data_path.to_csv("data_path.csv",index=False)
data_path.head()
# Out:
#   Emotions                                               Path
# 0    angry  C:/Users/naimu/Music/Speech Recognition ML DL ...
# 1  disgust  C:/Users/naimu/Music/Speech Recognition ML DL ...
# 2     fear  C:/Users/naimu/Music/Speech Recognition ML DL ...
# 3    happy  C:/Users/naimu/Music/Speech Recognition ML DL ...
# 4  neutral  C:/Users/naimu/Music/Speech Recognition ML DL ...

# %%
len(data_path)
# Out:
# 10722

# %%
print(data_path.Emotions.value_counts())
# Out:
# angry       1731
# disgust     1731
# fear        1731
# happy       1731
# sad         1731
# neutral     1607
# ps           400
# surprise      60
# Name: Emotions, dtype: int64

# %%
import librosa

# Load audio file
data, sr = librosa.load("C:/Users/naimu/Music/Speech Recognition ML DL AI/Dataset/surrey ALL/DC_a01.wav")

# Print the sampling rate
print("Sampling rate:", sr)
# Out:
# Sampling rate: 22050

# %%
ipd.Audio(data,rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# CREATE LOG MEL SPECTROGRAM
plt.figure(figsize=(10, 5))
spectrogram = librosa.feature.melspectrogram(y=data, sr=sr, n_mels=128,fmax=8000) 
log_spectrogram = librosa.power_to_db(spectrogram)
librosa.display.specshow(log_spectrogram, y_axis='mel', sr=sr, x_axis='time');
plt.title('Mel Spectrogram ')
plt.colorbar(format='%+2.0f dB')

# %%
# Save the plot to a file named "mel_spectrogram.png"
plt.savefig('mel_spectrogram.png')

# %%
mfcc = librosa.feature.mfcc(y=data, sr=sr, n_mfcc=30)


# MFCC
plt.figure(figsize=(16, 10))
plt.subplot(3,1,1)
librosa.display.specshow(mfcc, x_axis='time')
plt.ylabel('MFCC')
plt.colorbar()

ipd.Audio(data,rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Data augmentation

# %%
# NOISE
def noise(data):
    noise_amp = 0.035*np.random.uniform()*np.amax(data)
    data = data + noise_amp*np.random.normal(size=data.shape[0])
    return data

# STRETCH
def stretch(data, rate=0.8):
    return librosa.effects.time_stretch(data, rate)
# SHIFT
def shift(data):
    shift_range = int(np.random.uniform(low=-5, high = 5)*1000)
    return np.roll(data, shift_range)
# PITCH
def pitch(data, sampling_rate, pitch_factor=0.7):
    return librosa.effects.pitch_shift(y=data, sr=sampling_rate, n_steps=pitch_factor)

# %%
# NORMAL AUDIO


import librosa.display
plt.figure(figsize=(12, 5))
librosa.display.waveshow(y=data, sr=sr)
ipd.Audio(data,rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# AUDIO WITH NOISE
x = noise(data)
plt.figure(figsize=(12,5))
librosa.display.waveshow(y=x, sr=sr)
ipd.Audio(x, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# SHIFTED AUDIO
x = shift(data)
plt.figure(figsize=(12,5))
librosa.display.waveshow(y=x, sr=sr)
ipd.Audio(x, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Feature extraction

# %%
def zcr(data, frame_length, hop_length):
    # Compute zero-crossing rate
    zcr = librosa.feature.zero_crossing_rate(data, frame_length=frame_length, hop_length=hop_length)
    return np.squeeze(zcr)

def rmse(data, frame_length=2048, hop_length=512):
    # Compute Root Mean Square Energy (RMSE)
    rmse = librosa.feature.rms(y=data, frame_length=frame_length, hop_length=hop_length)
    return np.squeeze(rmse)

def mfcc(data, sr, frame_length=2048, hop_length=512, flatten=True):
    # Compute Mel-frequency cepstral coefficients (MFCC)
    mfcc_result = librosa.feature.mfcc(y=data, sr=sr, n_fft=frame_length, hop_length=hop_length)
    return np.squeeze(mfcc_result.T) if not flatten else np.ravel(mfcc_result.T)

def extract_features(data, sr=22050, frame_length=2048, hop_length=512):
    # Extract features from audio data
    result = np.array([])
    
    # Concatenate zero-crossing rate, RMSE, and MFCC features
    result = np.hstack((result,
                        zcr(data, frame_length, hop_length),
                        rmse(data, frame_length, hop_length),
                        mfcc(data, sr, frame_length, hop_length)
                        ))
    return result

def get_features(path, duration=2.5, offset=0.6):
    # Load audio file
    data, sr = librosa.load(path, duration=duration, offset=offset)
    
    # Extract features from original audio
    audio = extract_features(data)
    audio = np.array(audio)
    
    # Add features for noisy audio
    noised_audio = noise(data)
    aud2 = extract_features(noised_audio)
    audio = np.vstack((audio, aud2))
    
    # Add features for pitched audio
    pitched_audio = pitch(data, sr)
    aud3 = extract_features(pitched_audio)
    audio = np.vstack((audio, aud3))
    
    # Add features for pitched and noisy audio
    pitched_audio1 = pitch(data, sr)
    pitched_noised_audio = noise(pitched_audio1)
    aud4 = extract_features(pitched_noised_audio)
    audio = np.vstack((audio, aud4))
    
    return audio

# %%
import multiprocessing as mp
print("Number of processors: ", mp.cpu_count())
# Out:
# Number of processors:  16

# %%
# Get Features

# %%
import os
import timeit
from tqdm import tqdm

start = timeit.default_timer()
X, Y = [], []

# Provide the directory path
directory_path = "C:/Users/naimu/Music/Speech Recognition ML DL AI/Dataset/AudioWAV"

# Iterate over all audio files in the directory
for filename in tqdm(os.listdir(directory_path)):
    if filename.endswith(".wav"):
        path = os.path.join(directory_path, filename)
        features = get_features(path)
        for i in features:
            X.append(i)
            Y.append(emotion)  # Ensure 'emotion' is defined appropriately

print('Done')
stop = timeit.default_timer()

print('Time: ', stop - start)
len(X), len(Y), data_path.Path.shape
# Out:
# 100%|██████████| 7442/7442 [09:07<00:00, 13.60it/s]
# Done
# Time:  547.0400214999972

# %%
len(X), len(Y), data_path.Path.shape
# Out:
# (29768, 29768, (10722,))

# %%
Emotions = pd.DataFrame(X)
Emotions['Emotions'] = Y
Emotions.to_csv('emotion.csv', index=False)
Emotions.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.034180  0.069336  0.115723  0.148926  0.142090  0.130859  0.101562
# 1  0.119141  0.213867  0.310059  0.337891  0.292480  0.230469  0.163086
# 2  0.040527  0.082031  0.129883  0.144531  0.137695  0.117188  0.084961
# 3  0.048340  0.096680  0.142578  0.155273  0.143555  0.116211  0.085938
# 4  0.041504  0.059082  0.070312  0.062988  0.080566  0.128906  0.145508
#
#           7         8         9  ...  2367  2368  2369  2370  2371  2372  \
# 0  0.070801  0.069336  0.074219  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 1  0.119629  0.151855  0.156250  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 2  0.074219  0.067871  0.075195  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3  0.075195  0.066895  0.073242  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 4  0.146484  0.125977  0.072266  ...   NaN   NaN   NaN   NaN   NaN   NaN
#
#    2373  2374  2375  Emotions
# 0   NaN   NaN   NaN     angry
# 1   NaN   NaN   NaN     angry
# ...
